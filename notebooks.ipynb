# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
x = np.arange(0, 30)
y = [3, 4, 5, 7, 10, 8, 9, 10, 10, 23, 27, 44, 50, 63, 67, 60, 62, 70, 75, 88, 81, 87, 95, 100, 108, 135, 151, 160, 169, 179]
plt.figure(figsize=(10,6))
plt.scatter(x, y)
plt.show()



#data from 
x2 = np.arange(0,12)
y2 = [0.417 ,0.311, 0.233, 0.179,0.161, 0.121, 0.106, 0.084, 0.071, 0.062, 0.055, 0.048]
plt.figure(figsize=(10,6))
plt.scatter(x2, y2)
plt.show()

#data from
x3 = np.arange(0,24)
y3 = [1.8, 2.4, 1.5,2.3,1.7,2.0,1.7,2.1,1.6,2.0,1.9,1.7,2.1,1.6,1.8,2.2,1.7,2.1,1.9,1.7,1.8,1.4,2.6,2.4]
plt.figure(figsize=(10,6))
plt.scatter(x3, y3)
plt.show()


#data from
x3 = np.arange(0,24)
y3 = [1.8, 2.4, 1.5,2.3,1.7,2.0,1.7,2.1,1.6,2.0,1.9,1.7,2.1,1.6,1.8,2.2,1.7,2.1,1.9,1.7,1.8,1.4,2.6,2.4]
plt.figure(figsize=(10,6))
plt.scatter(x3, y3)
plt.show()


#data from
x4 = np.arange(0,17)
y4 = [4618,4467, 4404,4209,4163,4163, 4095,4035, 3963,3959,3891,3799,3739,3638,3598,3772,3532]
x5 = np.arange(0,17)
y5 = [80541,80982,78068,78535,74934,76393,72416,73832, 74037,71942, 73842, 69039,70160, 68230,66618,59421,61880]
plt.figure(figsize=(10,6))
plt.scatter(x4, y4)
plt.plot(x5,y5)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures


poly = PolynomialFeatures(degree=2, include_bias=False)

poly2 = PolynomialFeatures(degree=4, include_bias=False)
#degree determines the power the polynomial will be to
poly
# Out:
# PolynomialFeatures(include_bias=False)

# %%
poly_features = poly2.fit_transform(x.reshape(-1, 1))
#methods of fit and transform done at the same time to get a 2D array

poly_features_2 = poly.fit_transform(x2.reshape(-1,1))

X_train, X_test, y_train, y_test = train_test_split(x2, y2, test_size=0.1, shuffle=False)

poly_features_2b = poly.fit_transform(X_train.reshape(-1,1))

X_train3, X_test3, y_train3, y_test3 = train_test_split(x3, y3, test_size=0.2, shuffle=False)

poly_features_3 = poly.fit_transform(x3.reshape(-1,1))

poly_features_3b = poly.fit_transform(X_train3.reshape(-1,1))



X_train4, X_test4, y_train4, y_test4 = train_test_split(x4, y4, test_size=0.2, shuffle=False)

poly_features_4 = poly.fit_transform(x4.reshape(-1,1))

poly_features_4b = poly.fit_transform(X_train4.reshape(-1,1))


X_train5, X_test5, y_train5, y_test5 = train_test_split(x5, y5, test_size=0.15, shuffle=False)

poly_features_5 = poly.fit_transform(x5.reshape(-1,1))

poly_features_5b = poly.fit_transform(X_train5.reshape(-1,1))

# %%
from sklearn.linear_model import LinearRegression
poly_reg_model = LinearRegression()
poly_reg_model_2 = LinearRegression()
poly_reg_model_2b = LinearRegression()
poly_reg_model_3 = LinearRegression()
poly_reg_model_3b = LinearRegression()
poly_reg_model_4 = LinearRegression()
poly_reg_model_4b = LinearRegression()
poly_reg_model_5 = LinearRegression()
poly_reg_model_5b = LinearRegression()



#fits the model to the data

poly_reg_model.fit(poly_features, y)

poly_reg_model_2b.fit(poly_features_2b , y_train)

poly_reg_model_2.fit(poly_features_2 , y2)

poly_reg_model_3.fit(poly_features_3 , y3)

poly_reg_model_3b.fit(poly_features_3b , y_train3)

poly_reg_model_4.fit(poly_features_4 , y4)

poly_reg_model_4b.fit(poly_features_4b , y_train4)

poly_reg_model_5.fit(poly_features_5 , y5)

poly_reg_model_5b.fit(poly_features_5b , y_train5)
# Out:
# LinearRegression()

# %%
y_predicted = poly_reg_model.predict(poly_features)


tX=poly.fit_transform(X_test.reshape(-1,1))
y_predicted_2b = poly_reg_model_2b.predict(tX)
#rmse = np.sqrt(mean_squared_error(y_test, y_predicted_2))

y_predicted_2 = poly_reg_model_2.predict(poly_features_2)

y_predicted_3 = poly_reg_model_3.predict(poly_features_3)

y_predicted_3b = poly_reg_model_3b.predict(poly_features_3b)

tX3=poly.fit_transform(X_test3.reshape(-1,1))
y_predicted_3b = poly_reg_model_3b.predict(tX3)


y_predicted_4 = poly_reg_model_4.predict(poly_features_4)

y_predicted_4b = poly_reg_model_4b.predict(poly_features_4b)

tX4=poly.fit_transform(X_test4.reshape(-1,1))
y_predicted_4b = poly_reg_model_4b.predict(tX4)

y_predicted_5 = poly_reg_model_5.predict(poly_features_5)

y_predicted_5b = poly_reg_model_5b.predict(poly_features_5b)

tX5=poly.fit_transform(X_test5.reshape(-1,1))
y_predicted_5b = poly_reg_model_5b.predict(tX5)

rmse = np.sqrt(mean_squared_error(y_test4, y_predicted_4b))
rmse
# Out:
# 120.57695535372036

# %%
#puts the model onto the graph with the trained model besides it

plt.figure(figsize=(4, 4))
plt.title("Testing polynomial regression", size=16)
plt.scatter(x, y)
plt.plot(x, y_predicted, c="red")
plt.show()

plt.figure(figsize=(4, 4))
plt.title("Localized cost of electricity solar energy USD/kWh", size=16)
plt.scatter(x2,y2)
plt.scatter(X_test, y_test)
plt.plot(x2, y_predicted_2, c="blue")
plt.plot(X_test, y_predicted_2b, c="red")
plt.show()

plt.figure(figsize=(4, 4))
plt.title("January's average sun hours", size=16)
plt.scatter(x3, y3)
plt.scatter(X_test3, y_test3)
plt.plot(x3, y_predicted_3, c="red")
plt.plot(X_test3, y_predicted_3b, c="blue")
plt.show()

plt.figure(figsize=(3, 3))
plt.title("domestic energy usage kwH mean per meter", size=16)
plt.scatter(x4, y4)
plt.scatter(X_test4, y_test4)
plt.plot(x4, y_predicted_4 ,label="Predicted")
plt.plot(X_test4, y_predicted_4b,label="trained")
plt.show()

plt.figure(figsize=(4, 4))
plt.title("non domestic energy usage kwH mean per meter", size=16)
plt.scatter(x5, y5)
plt.scatter(X_test5, y_test5)
plt.plot(x5, y_predicted_5, c="red")
plt.plot(X_test5, y_predicted_5b, c="blue")
plt.show()

#from sklearn.model_selection import cross_val_score

# instantiate the linear regression algorithm
#lr1 = LinearRegression()

# conduct k-fold cross-validation on the whole dataset
#cross_val_score(poly_reg_model_4.reshape(-1,1), x4, y4, cv=3, scoring='neg_mean_squared_error').mean()*-1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_72464\1691852293.py in <module>
#      44
#      45 # conduct k-fold cross-validation on the whole dataset
# ---> 46 cross_val_score(poly_reg_model_4.reshape(-1,1), x4, y4, cv=3, scoring='neg_mean_squared_error').mean()*-1
#
# AttributeError: 'LinearRegression' object has no attribute 'reshape'

# %%
#part 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
np.random.seed(1)
x_1 = np.absolute(np.random.randn(100, 1) * 10)
x_2 = np.absolute(np.random.randn(100, 1) * 30)
y = 2*x_1**2 + 3*x_1 + 2 + np.random.randn(100, 1)*20

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 4))
axes[0].scatter(x_1, y)
axes[1].scatter(x_2, y)
axes[0].set_title("x_1 plotted")
axes[1].set_title("x_2 plotted")
plt.show()

# %%
df = pd.DataFrame({"x_1":x_1.reshape(100,), "x_2":x_2.reshape(100,), "y":y.reshape(100,)}, index=range(0,100))
df

#stores them in the dataframe

# %%
from sklearn.model_selection import train_test_split
#train_test_split helps us split our data into a training and a test dataset:

X, y = df[["x_1", "x_2"]], df["y"]
poly = PolynomialFeatures(degree=2, include_bias=False)
poly_features = poly.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.3, random_state=42)

# %%
poly_reg_model = LinearRegression()
poly_reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
poly_reg_y_predicted = poly_reg_model.predict(X_test)
from sklearn.metrics import mean_squared_error
poly_reg_rmse = np.sqrt(mean_squared_error(y_test, poly_reg_y_predicted))
poly_reg_rmse
# Out:
# 20.937707839078747

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
lin_reg_model = LinearRegression()
lin_reg_model.fit(X_train, y_train)
lin_reg_y_predicted = lin_reg_model.predict(X_test)
lin_reg_rmse = np.sqrt(mean_squared_error(y_test, lin_reg_y_predicted))
lin_reg_rmse
# Out:
# 62.302487453878506

# %%
lin_reg_model.coef_
# Out:
# array([43.73176255, -0.53140809])

# %%
lin_reg_model.intercept_
# Out:
# -117.07280081594811

# %%
#X_train[:,0] for plotting as X_train is a 2D array not 1D

plt.scatter(X_train.iloc[:,0], y_train, label='Actual Data', color='b')
plt.plot(X.iloc[:30,0], lin_reg_y_predicted, label='Regression Line', color='r')
plt.plot(X.iloc[:30,0], poly_reg_y_predicted, label='CumulativeRegression Line', color='g')
plt.xlabel('Year')
plt.ylabel('Energy from renewable & waste sources')
plt.title('Energy from Renewable & Waste Sources vs. Year')
plt.legend()
plt.show()

# %%
X
# Out:
#           x_1        x_2
# 0   16.243454  13.413857
# 1    6.117564  36.735231
# 2    5.281718  12.104749
# 3   10.729686  17.807356
# 4    8.654076  32.847355
# ..        ...        ...
# 95   0.773401  48.823150
# 96   3.438537  18.069578
# 97   0.435969  12.608466
# 98   6.200008  24.328550
# 99   6.980320  31.333263
#
# [100 rows x 2 columns]

# %%
X.iloc[:30,0]
# Out:
# 0     16.243454
# 1      6.117564
# 2      5.281718
# 3     10.729686
# 4      8.654076
# 5     23.015387
# 6     17.448118
# 7      7.612069
# 8      3.190391
# 9      2.493704
# 10    14.621079
# 11    20.601407
# 12     3.224172
# 13     3.840544
# 14    11.337694
# 15    10.998913
# 16     1.724282
# 17     8.778584
# 18     0.422137
# 19     5.828152
# 20    11.006192
# 21    11.447237
# 22     9.015907
# 23     5.024943
# 24     9.008559
# 25     6.837279
# 26     1.228902
# 27     9.357694
# 28     2.678881
# 29     5.303555
# Name: x_1, dtype: float64
