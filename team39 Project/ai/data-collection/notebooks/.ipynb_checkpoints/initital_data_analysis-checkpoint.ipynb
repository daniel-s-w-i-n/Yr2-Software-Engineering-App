# %%
# Cell 1: Title and Introduction
"""
# Initial Data Check for PV Data Analysis
This notebook performs an initial check on the harvested PV data to ensure its integrity and to understand its structure.
"""

# %%
# Cell 2: Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set any global parameters or styles for plotting
plt.style.use('seaborn-darkgrid')

# %%
# Cell 3: Load the Data
# Replace 'path_to_dataset.csv' with the actual file path of your dataset
data = pd.read_csv('../data/Weather Data 2014-11-30.xlsx')

# %%
# Cell 4: Preliminary Data Inspection
# Display the first few rows to get an overview of the data
print(data.head())

# Display data types and non-null counts
print(data.info())

# %%
# Cell 5: Check for Missing Values
# Summarize missing values for each column
missing_values = data.isnull().sum()
print(missing_values)

# %%
# Cell 6: Basic Statistical Overview
# Generate descriptive statistics to understand the distribution of data
print(data.describe())

# %%
# Cell 7: Initial Data Quality Assessment
# Check for duplicate entries
duplicates = data.duplicated().sum()
print(f"Number of duplicate entries: {duplicates}")

# Check for anomalies or outliers in the data
# For numerical data, this could involve looking at the min and max values for reasonableness
# For example:
for column in data.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(10, 4))
    sns.boxplot(data[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %%
# Cell 8: Categorical Data Overview
# If the data contains categorical features, explore the unique values and their counts
# For example:
for column in data.select_dtypes(include='object').columns:
    print(f"Unique values for {column}:")
    print(data[column].value_counts())
    print("\n")

# %%
# Cell 9: Data Distribution Visualization
# Visualize the distribution of key variables using histograms or KDE plots
# For example:
for column in data.select_dtypes(include=np.number).columns:
    plt.figure(figsize=(10, 4))
    sns.histplot(data[column], kde=True, bins=30)
    plt.title(f'Distribution of {column}')
    plt.show()

# %%
# Cell 10: Correlation Analysis (if applicable)
# If there are multiple numerical features, a correlation matrix can be helpful
correlation_matrix = data.corr()
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Cell 11: Conclusion of Initial Data Check
"""
# Conclusion
Summarize the findings from the initial data check, including data quality, missing values, and potential next steps.
"""
